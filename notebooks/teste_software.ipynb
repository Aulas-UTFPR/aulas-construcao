# %% [markdown]
# # Aula de Teste de Software com Python
#
# Obs.: *Notebook gerado com o auxílio de LLM.*
#
# Este notebook demonstra como escrever testes automatizados com `pytest` e medir cobertura de código com `coverage`.
#
# Antes de mais nada, é necessário montar o seu diretírio de trabalho no Google Drive:

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
save_path = '/content/drive/MyDrive/teste_software_aula'

# %%
import os

os.makedirs(save_path, exist_ok=True)

# %% [markdown]
# ## 1. Instalando dependências

# %%
# !pip install pytest coverage -q
# Out:
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 244.6/244.6 kB 4.7 MB/s eta 0:00:00

# %% [markdown]
# ## 2. Criando um módulo de exemplo

# %%
# %%writefile calculadora.py

def soma(a, b):
    return a + b

def subtrai(a, b):
    return a - b

def multiplica(a, b):
    return a * b

def divide(a, b):
    if b == 0:
        raise ValueError("Divisão por zero não é permitida.")
    return a / b
# Out:
# Writing calculadora.py

# %% [markdown]
# ## 3. Escrevendo testes com Pytest

# %%
# %%writefile test_calculadora.py
from calculadora import soma, subtrai, multiplica, divide
import pytest

def test_soma():
    assert soma(2, 3) == 5

def test_subtrai():
    assert subtrai(5, 3) == 2

def test_multiplica():
    assert multiplica(4, 3) == 12

def test_divide():
    assert divide(10, 2) == 5

def test_divide_por_zero():
    with pytest.raises(ValueError):
        divide(10, 0)
# Out:
# Writing test_calculadora.py

# %% [markdown]
# ## 4. Executando os testes

# %%
# !pytest test_calculadora.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.3.5, pluggy-1.6.0
# rootdir: /content
# plugins: anyio-4.9.0, langsmith-0.3.45, typeguard-4.4.3
# collected 5 items
#
# test_calculadora.py .....                                                [100%]
#
# ============================== 5 passed in 0.01s ===============================

# %% [markdown]
# ## 5. Verificando cobertura de código

# %%
# !coverage run -m pytest test_calculadora.py
# Out:
# ============================= test session starts ==============================
# platform linux -- Python 3.11.13, pytest-8.3.5, pluggy-1.6.0
# rootdir: /content
# plugins: anyio-4.9.0, langsmith-0.3.45, typeguard-4.4.3
# collected 5 items
#
# test_calculadora.py .....                                                [100%]
#
# ============================== 5 passed in 0.01s ===============================

# %%
# !coverage report -m
# !coverage html
# Out:
# Name                  Stmts   Miss  Cover   Missing
# ---------------------------------------------------
# calculadora.py           10      0   100%
# test_calculadora.py      13      0   100%
# ---------------------------------------------------
# TOTAL                    23      0   100%
# Wrote HTML report to htmlcov/index.html

# %%
# Copiar toda a pasta htmlcov para o Drive
# !cp -r htmlcov /content/drive/MyDrive/teste_software_aula/

# %% [markdown]
# ## 6. Conclusão
#
# Neste notebook, vimos como:
# - Criar código Python simples;
# - Escrever testes com `pytest`;
# - Utilizar `coverage` para medir a cobertura dos testes.
